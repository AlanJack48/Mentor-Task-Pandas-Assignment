# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanJack48/Mentor-Task-Pandas-Assignment/blob/main/DW23_Mentor_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment 1
# There is a data set named 'Balance scale data' in UCI.
# Link: https://archive.ics.uci.edu/ml/datasets/balance+scale

# %%
# DataCleaning ---> 'Class Name','Left-Weight','Left-Distance','Right-Weight','Right-Distance'

# %%
import pandas as pd

# %%
column_names = ['Class Name','Left-Weight','Left-Distance','Right-Weight','Right-Distance']

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/balance-scale/balance-scale.data',names=column_names)

# %%
df
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
# [625 rows x 5 columns]

# %%
df.shape
# Out:
# (625, 5)

# %%
df['Class Name'].unique()
# Out:
# array(['B', 'R', 'L'], dtype=object)

# %%
df['Class Name'].nunique()
# Out:
# 3

# %%
X = df.iloc[:,[0,1,2,3,4]] 
X
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
# [625 rows x 5 columns]

# %%
y = df.iloc[:,-1]
y
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 620    1
# 621    2
# 622    3
# 623    4
# 624    5
# Name: Right-Distance, Length: 625, dtype: int64

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
c = df.iloc[:,[1,2,3,4]]
c
# Out:
#      Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0              1              1             1               1
# 1              1              1             1               2
# 2              1              1             1               3
# 3              1              1             1               4
# 4              1              1             1               5
# ..           ...            ...           ...             ...
# 620            5              5             5               1
# 621            5              5             5               2
# 622            5              5             5               3
# 623            5              5             5               4
# 624            5              5             5               5
#
# [625 rows x 4 columns]

# %%
df['Left-Weight'].mean()
# Out:
# 3.0

# %%
df['Left-Distance'].mean()
# Out:
# 3.0

# %%
df['Right-Distance'].mean()
# Out:
# 3.0

# %%
df['Right-Weight'].mean()
# Out:
# 3.0

# %%
df[["Right-Distance", "Right-Weight"]].describe()
# Out:
#        Right-Distance  Right-Weight
# count      625.000000    625.000000
# mean         3.000000      3.000000
# std          1.415346      1.415346
# min          1.000000      1.000000
# 25%          2.000000      2.000000
# 50%          3.000000      3.000000
# 75%          4.000000      4.000000
# max          5.000000      5.000000

# %%
df
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
# [625 rows x 5 columns]

# %%
df["Total_R_L-Dist_weight"] = df.iloc[:,1:5].sum(axis=1)
df
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance  \
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
#      Total_R_L-Dist_weight
# 0                        4
# 1                        5
# ...

# %%
del df['Total_R_L-Dist_weight']

# %%
df
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0            B            1              1             1               1
# 1            R            1              1             1               2
# 2            R            1              1             1               3
# 3            R            1              1             1               4
# 4            R            1              1             1               5
# ..         ...          ...            ...           ...             ...
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
# 624          B            5              5             5               5
#
# [625 rows x 5 columns]

# %%
df_gb = df.groupby('Class Name')
df_gb

# %%
df_gb.get_group('L')
# Out:
#     Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 25           L            1              2             1               1
# 50           L            1              3             1               1
# 51           L            1              3             1               2
# 55           L            1              3             2               1
# 75           L            1              4             1               1
# ..         ...          ...            ...           ...             ...
# 619          L            5              5             4               5
# 620          L            5              5             5               1
# 621          L            5              5             5               2
# 622          L            5              5             5               3
# 623          L            5              5             5               4
#
# [288 rows x 5 columns]

# %%
df_gb.get_group('R').mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Left-Weight       2.399306
# Left-Distance     2.399306
# Right-Weight      3.611111
# Right-Distance    3.611111
# dtype: float64

# %%
df_gb.get_group('R').std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Left-Weight       1.331840
# Left-Distance     1.331840
# Right-Weight      1.227508
# Right-Distance    1.227508
# dtype: float64

# %%
df_gb.get_group('L').mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Left-Weight       3.611111
# Left-Distance     3.611111
# Right-Weight      2.399306
# Right-Distance    2.399306
# dtype: float64

# %%
df_gb.get_group('L').std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Left-Weight       1.227508
# Left-Distance     1.227508
# Right-Weight      1.331840
# Right-Distance    1.331840
# dtype: float64

# %%
df_gb.get_group('B').mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Left-Weight       2.938776
# Left-Distance     2.938776
# Right-Weight      2.938776
# Right-Distance    2.938776
# dtype: float64

# %%
df[["Class Name", "Left-Distance"]].groupby("Class Name").mean()
# Out:
#             Left-Distance
# Class Name
# B                2.938776
# L                3.611111
# R                2.399306

# %%
df.isnull()
# Out:
#      Class Name  Left-Weight  Left-Distance  Right-Weight  Right-Distance
# 0         False        False          False         False           False
# 1         False        False          False         False           False
# 2         False        False          False         False           False
# 3         False        False          False         False           False
# 4         False        False          False         False           False
# ..          ...          ...            ...           ...             ...
# 620       False        False          False         False           False
# 621       False        False          False         False           False
# 622       False        False          False         False           False
# 623       False        False          False         False           False
# 624       False        False          False         False           False
#
# [625 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Class Name        0
# Left-Weight       0
# Left-Distance     0
# Right-Weight      0
# Right-Distance    0
# dtype: int64

# %%
# Assignment 2
# Write a function compute_dist() that accepts a list of values as input and outputs a dictionary
# storing the distribution of the data represented by the list. Here, distribution means tracking how
# many times each element is appearing in the given list.

# Ex Usage:
    # l1 = [3, 4, 2, 1, 5, 1, 2, 4, 3, 4]
    # d1 = compute_dist(l1)

# d1 should be {1: 2, 2: 2, 3: 2, 4: 3, 5: 1}

# %%
l1 =[3, 4, 2, 1, 5, 1, 2, 4, 3, 4]
def Compute_dist(l1):
    d = dict((x,l1.count(x)) for x in set(l1))
    return d

print("d1:",Compute_dist(l1))
# Out:
# d1: {1: 2, 2: 2, 3: 2, 4: 3, 5: 1}
